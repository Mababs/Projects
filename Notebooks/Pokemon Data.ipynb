# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Pokemon.csv" , encoding = "latin 1" )
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df.shape
# Out:
# (151, 13)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
df_legendaries = df[df["Legendary"] == True]
df_legendaries
# Out:
#        #      Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 143  144  Articuno       Ice  Flying    580   90      85      100       95
# 144  145    Zapdos  Electric  Flying    580   90      90       85      125
# 145  146   Moltres      Fire  Flying    580   90     100       90      125
# 149  150    Mewtwo   Psychic     NaN    680  106     110       90      154
#
#      Sp. Def  Speed  Stage  Legendary
# 143      125     85      1       True
# 144       90    100      1       True
# 145       85     90      1       True
# 149       90    130      1       True

# %%
sns.lmplot(x="Attack", y = "Defense", hue = "Stage", fit_reg = False, data = df)

# %%
df.sort_values('Attack', ascending = False)
# Out:
#        #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 148  149   Dragonite    Dragon   Flying    600   91     134       95      100
# 111  112      Rhydon    Ground     Rock    485  105     130      120       45
# 135  136     Flareon      Fire      NaN    525   65     130       60       95
# 67    68     Machamp  Fighting      NaN    505   90     130       80       65
# 98    99     Kingler     Water      NaN    475   55     130      115       50
# 126  127      Pinsir       Bug      NaN    500   65     125      100       55
# 129  130    Gyarados     Water   Flying    540   95     125       79       60
# 105  106   Hitmonlee  Fighting      NaN    455   50     120       53       35
# 75    76       Golem      Rock   Ground    495   80     120      130       55
# 140  141    Kabutops      Rock    Water    495   60     115      105       65
# 84    85      Dodrio    Normal   Flying    460   60     110       70       60
# 122  123     Scyther       Bug   Flying    500   70     110       80       55
# 58    59    Arcanine      Fire      NaN    555   90     110       80      100
# 149  150      Mewtwo   Psychic      NaN    680  106     110       90      154
# 142  143     Snorlax    Normal      NaN    540  160     110       65       65
# 56    57    Primeape  Fighting      NaN    455   65     105       60       60
# 70    71  Victreebel     Grass   Poison    490   80     105       65      100
# 88    89         Muk    Poison      NaN    500  105     105       75       65
# 97    98      Krabby     Water      NaN    325   30     105       90       25
# 106  107  Hitmonchan  Fighting      NaN    455   50     105       79       35
# 141  142  Aerodactyl      Rock   Flying    515   80     105       65       60
# 33    34    Nidoking    Poison   Ground    505   81     102       77       85
# 127  128      Tauros    Normal      NaN    490   75     100       95       40
# 77    78    Rapidash      Fire      NaN    500   65     100       70       80
# 145  146     Moltres      Fire   Flying    580   90     100       90      125
# 66    67     Machoke  Fighting      NaN    405   80     100       70       50
# 27    28   Sandslash    Ground      NaN    450   75     100      110       45
# 150  151         Mew   Psychic      NaN    600  100     100      100      100
# 74    75    Graveler      Rock   Ground    390   55      95      115       45
# 90    91    Cloyster     Water      Ice    525   50      95      180       85
# ..   ...         ...       ...      ...    ...  ...     ...      ...      ...
# 131  132       Ditto    Normal      NaN    288   48      48       48       48
# 6      7    Squirtle     Water      NaN    314   44      48       65       50
# 95    96     Drowzee   Psychic      NaN    328   60      48       45       43
# 28    29  NidoranªÛ    Poison      NaN    275   55      47       52       40
# 34    35    Clefairy     Fairy      NaN    323   70      45       48       60
# 38    39  Jigglypuff    Normal    Fairy    270  115      45       20       45
# 40    41       Zubat    Poison   Flying    245   40      45       35       30
# 51    52      Meowth    Normal      NaN    290   40      45       35       40
# 85    86        Seel     Water      NaN    325   65      45       55       45
# 15    16      Pidgey    Normal   Flying    251   40      45       40       35
# 121  122    Mr. Mime   Psychic    Fairy    460   40      45       65      100
# 94    95        Onix      Rock   Ground    385   35      45      160       30
# 119  120      Staryu     Water      NaN    340   30      45       55       70
# 11    12  Butterfree       Bug   Flying    395   60      45       50       90
# 36    37      Vulpix      Fire      NaN    299   38      41       40       50
# 115  116      Horsea     Water      NaN    295   30      40       70       70
# 137  138     Omanyte      Rock    Water    355   35      40      100       90
# 101  102   Exeggcute     Grass  Psychic    325   60      40       80       60
# 71    72   Tentacool     Water   Poison    335   40      40       35       50
# 12    13      Weedle       Bug   Poison    195   40      35       30       20
# 91    92      Gastly     Ghost   Poison    310   30      35       30      100
# 80    81   Magnemite  Electric    Steel    325   25      35       70       95
# 63    64     Kadabra   Psychic      NaN    400   40      35       30      120
# 99   100     Voltorb  Electric      NaN    330   40      30       50       55
# 9     10    Caterpie       Bug      NaN    195   45      30       35       20
# 13    14      Kakuna       Bug   Poison    205   45      25       50       25
# 62    63        Abra   Psychic      NaN    310   25      20       15      105
# 10    11     Metapod       Bug      NaN    205   50      20       55       25
# 128  129    Magikarp     Water      NaN    200   20      10       55       15
# 112  113     Chansey    Normal      NaN    450  250       5        5       35
#
#      Sp. Def  Speed  Stage  Legendary
# 148      100     80      3      False
# 111       45     40      2      False
# 135      110     65      2      False
# 67        85     55      3      False
# 98        50     75      2      False
# 126       70     85      1      False
# 129      100     81      2      False
# 105      110     87      1      False
# 75        65     45      3      False
# 140       70     80      2      False
# 84        60    100      2      False
# 122       80    105      1      False
# 58        80     95      2      False
# 149       90    130      1       True
# 142      110     30      1      False
# 56        70     95      2      False
# 70        70     70      3      False
# 88       100     50      2      False
# 97        25     50      1      False
# 106      110     76      1      False
# 141       75    130      1      False
# 33        75     85      3      False
# 127       70    110      1      False
# 77        80    105      2      False
# 145       85     90      1       True
# 66        60     45      2      False
# 27        55     65      2      False
# 150      100    100      1      False
# 74        45     35      2      False
# 90        45     70      2      False
# ..       ...    ...    ...        ...
# 131       48     48      1      False
# 6         64     43      1      False
# 95        90     42      1      False
# 28        40     41      1      False
# 34        65     35      1      False
# 38        25     20      1      False
# 40        40     55      1      False
# 51        40     90      1      False
# 85        70     45      1      False
# 15        35     56      1      False
# 121      120     90      1      False
# 94        45     70      1      False
# 119       55     85      1      False
# 11        80     70      3      False
# 36        65     65      1      False
# 115       25     60      1      False
# 137       55     35      1      False
# 101       45     40      1      False
# 71       100     70      1      False
# 12        20     50      1      False
# 91        35     80      1      False
# 80        55     45      1      False
# 63        70    105      2      False
# 99        55    100      1      False
# 9         20     45      1      False
# 13        25     35      2      False
# 62        55     90      1      False
# 10        25     30      2      False
# 128       20     80      1      False
# 112      105     50      1      False
#
# [151 rows x 13 columns]

# %%
df_small = df[["Attack", "Defense"]]
sns.boxplot(data=df_small)

# %%
df["ADsum"] = df["Attack"] + df["Defense"]

# %%
sns.countplot(x= "Type 2", data=df)

# %%
df[(df["Type 1"] == "Fairy") | (df["Type 2"] == "Fairy")]
# Out:
#        #        Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 34    35    Clefairy    Fairy    NaN    323   70      45       48       60
# 35    36    Clefable    Fairy    NaN    483   95      70       73       95
# 38    39  Jigglypuff   Normal  Fairy    270  115      45       20       45
# 39    40  Wigglytuff   Normal  Fairy    435  140      70       45       85
# 121  122    Mr. Mime  Psychic  Fairy    460   40      45       65      100
#
#      Sp. Def  Speed  Stage  Legendary  ADsum
# 34        65     35      1      False     93
# 35        90     60      2      False    143
# 38        25     20      1      False     65
# 39        50     45      2      False    115
# 121      120     90      1      False    110

# %%
df[df["Type 1"] == "Water"]
# Out:
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 6      7    Squirtle  Water       NaN    314   44      48       65       50
# 7      8   Wartortle  Water       NaN    405   59      63       80       65
# 8      9   Blastoise  Water       NaN    530   79      83      100       85
# 53    54     Psyduck  Water       NaN    320   50      52       48       65
# 54    55     Golduck  Water       NaN    500   80      82       78       95
# 59    60     Poliwag  Water       NaN    300   40      50       40       40
# 60    61   Poliwhirl  Water       NaN    385   65      65       65       50
# 61    62   Poliwrath  Water  Fighting    510   90      95       95       70
# 71    72   Tentacool  Water    Poison    335   40      40       35       50
# 72    73  Tentacruel  Water    Poison    515   80      70       65       80
# 78    79    Slowpoke  Water   Psychic    315   90      65       65       40
# 79    80     Slowbro  Water   Psychic    490   95      75      110      100
# 85    86        Seel  Water       NaN    325   65      45       55       45
# 86    87     Dewgong  Water       Ice    475   90      70       80       70
# 89    90    Shellder  Water       NaN    305   30      65      100       45
# 90    91    Cloyster  Water       Ice    525   50      95      180       85
# 97    98      Krabby  Water       NaN    325   30     105       90       25
# 98    99     Kingler  Water       NaN    475   55     130      115       50
# 115  116      Horsea  Water       NaN    295   30      40       70       70
# 116  117      Seadra  Water       NaN    440   55      65       95       95
# 117  118     Goldeen  Water       NaN    320   45      67       60       35
# 118  119     Seaking  Water       NaN    450   80      92       65       65
# 119  120      Staryu  Water       NaN    340   30      45       55       70
# 120  121     Starmie  Water   Psychic    520   60      75       85      100
# 128  129    Magikarp  Water       NaN    200   20      10       55       15
# 129  130    Gyarados  Water    Flying    540   95     125       79       60
# 130  131      Lapras  Water       Ice    535  130      85       80       85
# 133  134    Vaporeon  Water       NaN    525  130      65       60      110
#
#      Sp. Def  Speed  Stage  Legendary  ADsum
# 6         64     43      1      False    113
# 7         80     58      2      False    143
# 8        105     78      3      False    183
# 53        50     55      1      False    100
# 54        80     85      2      False    160
# 59        40     90      1      False     90
# 60        50     90      2      False    130
# 61        90     70      3      False    190
# 71       100     70      1      False     75
# 72       120    100      2      False    135
# 78        40     15      1      False    130
# 79        80     30      2      False    185
# 85        70     45      1      False    100
# 86        95     70      2      False    150
# 89        25     40      1      False    165
# 90        45     70      2      False    275
# 97        25     50      1      False    195
# 98        50     75      2      False    245
# 115       25     60      1      False    110
# 116       45     85      2      False    160
# 117       50     63      1      False    127
# 118       80     68      2      False    157
# 119       55     85      1      False    100
# 120       85    115      2      False    160
# 128       20     80      1      False     65
# 129      100     81      2      False    204
# 130       95     60      1      False    165
# 133       95     65      2      False    125
